# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('Ecommerce Purchases.csv')

# %%
ecome=pd.DataFrame(data)

# %%
(ecome)
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 1550              Unit 6464 Box 1867\nDPO AE 64264-4077  07 fR       PM
# 1551       899 Kenneth Course\nNew Renee, FL 79150-4075  47 Fg       PM
# 1552  12886 Hernandez Plaza Suite 231\nPort Shawn, A...  55 oS       PM
# 1553  883 Hunt Squares\nEast Belindafurt, NJ 74861-2239  12 mh       AM
# 1554       928 Austin Tunnel\nWest Jeremytown, AZ 11979  56 EE       PM
#
#                                            Browser Info  \
# ...

# %%
ecome.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
ecome.describe()
# Out:
#         Credit Card  CC Security Code  Purchase Price
# count  1.555000e+03       1554.000000     1554.000000
# mean   2.300801e+15        883.466538       50.150933
# std    2.275682e+15       1580.150936       29.096222
# min    2.100293e+09          1.000000        0.030000
# 25%    3.051437e+13        278.000000       24.185000
# 50%    8.699828e+14        537.500000       50.980000
# 75%    4.474474e+15        807.000000       75.687500
# max    6.012000e+15       9988.000000       99.790000

# %%
ecome.count()
# Out:
# Address             1555
# Lot                 1555
# AM or PM            1555
# Browser Info        1555
# Company             1555
# Credit Card         1555
# CC Exp Date         1554
# CC Security Code    1554
# CC Provider         1554
# Email               1554
# Job                 1554
# IP Address          1554
# Language            1554
# Purchase Price      1554
# dtype: int64

# %%
ecome['Purchase Price'].mean()
# Out:
# 50.15093307593307

# %%
ecome['Purchase Price'].min()
# Out:
# 0.03

# %%
ecome['Purchase Price'].max()
# Out:
# 99.79

# %%
lang=ecome.loc[ecome['Language']=='en']
lang.count()
# Out:
# Address             175
# Lot                 175
# AM or PM            175
# Browser Info        175
# Company             175
# Credit Card         175
# CC Exp Date         175
# CC Security Code    175
# CC Provider         175
# Email               175
# Job                 175
# IP Address          175
# Language            175
# Purchase Price      175
# dtype: int64

# %%
job=ecome.loc[ecome['Job']=='Lawyer']
job.count()
# Out:
# Address             3
# Lot                 3
# AM or PM            3
# Browser Info        3
# Company             3
# Credit Card         3
# CC Exp Date         3
# CC Security Code    3
# CC Provider         3
# Email               3
# Job                 3
# IP Address          3
# Language            3
# Purchase Price      3
# dtype: int64

# %%
SplitedData=data[['Designation','Filed']]=ecome['Job'].str.split(',',expand=True)

# %%
SplitedData
# Out:
#                              0                             1
# 0                    Scientist   product/process development
# 1            Drilling engineer                          None
# 2     Customer service manager                          None
# 3            Drilling engineer                          None
# 4                  Fine artist                          None
# ...                        ...                           ...
# 1550                 Solicitor                      Scotland
# 1551         Minerals surveyor                          None
# 1552  Technical sales engineer                          None
# 1553  Local government officer                          None
# 1554                       NaN                           NaN
#
# [1555 rows x 2 columns]

# %%
plt.title("Bar graph ")
plt.bar(ecome['Purchase Price'], height=5)
plt.show()

# %%
plt.title("Histogram graph ")
plt.hist(ecome['Purchase Price'], bins=8)
plt.show()

# %%
feedata = pd.read_csv('fdata.csv', sep=',', parse_dates=True, index_col=0)
feedata.plot()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#xpoints = np.array([1,4,5,6,7])
ypoints = np.array([2,6,3,6,3])

plt.plot(ypoints, 'o:r')

plt.show()
