# %%
import matplotlib.pyplot as plt
petrol_prices=[65, 70, 80, 90, 100, 110, 115, 117, 120, 130, 135, 140]
petrol_prices1=[15, 170, 80, 90, 140, 160, 115, 117, 10, 140, 155, 150]
Months=["Jan", "Feb", "Mar", "Apr", "May", "June", "July", "Aug", "Sep", "Oct", "Nov", "Dec"]
plt.xlabel("Months")
plt.ylabel("Petrol Prices")
plt.title("Petrol Prices Inflamation")
plt.legend
plt.plot(Months, petrol_prices,petrol_prices1)
plt.show()

plt.xlabel("Months")
plt.ylabel("Petrol Prices")
plt.title("Petrol Prices Inflamation")
plt.scatter(Months, petrol_prices)
plt.show()

plt.xlabel("Months")
plt.ylabel("Petrol Prices")
plt.title("Petrol Prices Inflamation")
plt.hist(petrol_prices, bins=4)
plt.show()


plt.xlabel("Months")
plt.ylabel("Petrol Prices")
plt.title("Petrol Prices Inflamation")
plt.bar(Months, petrol_prices)
plt.show()

plt.xlabel("Months")
plt.ylabel("Petrol Prices")
plt.title("Petrol Prices Inflamation")
plt.pie(petrol_prices)
plt.show()
